# %%
import baltic as bt
from matplotlib import pyplot as plt
from collections import defaultdict
from matplotlib import cm
from numpy import linspace
# %matplotlib inline
import json
import matplotlib.gridspec as gridspec
import math
from itertools import combinations
import pandas as pd
import numpy as np
import seaborn as sns
from pprint import pprint
import math
import sequtils as sue
from scipy.stats import linregress
# Out:
# /Library/Python/2.7/site-packages/matplotlib/__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
tree_path = '../../data/frequencies/dengue_nicaragua_tree.json'
freqs_path = '../../data/frequencies/dengue_nicaragua_frequencies.json'
reference_path = '../../data/reference_seqs/genotype_refs_pyke2016.csv'
titer_path = '../../data/katzelnick2015/processed/genotypes_normalized.csv'

# %%
def assign_genotype_attr(tree, mrcas):
    ''' Takes the most basal node with each genotype annotation, 
    propagates the genotype assignment to its monophyletic descendents'''
    
    for k in tree.Objects: # remove old annotations
        k.traits = { key:value for key,value in k.traits.items()
                    if key not in ['genotype', 'genotype_mrca', 'clade_name']}
        
    for genotype, node in mrcas.items():
        node.traits['genotype_mrca'] = True
        node.traits['genotype'] = genotype
        for child in tree.traverse_tree(node, include_all=True):
            if 'genotype' in child.traits:
                if genotype != child.traits['genotype']:
                    print 'ERROR: Overlapping genotypes %s and %s at index %s'%(child.traits['genotype'], genotype, child.index)
            child.traits['genotype'] = genotype
    return tree

def load_tree_find_mrcas(path = tree_path):    
    '''Initially, genotype mrcas are as designated by augur.'''
    tree = bt.loadJSON(path) ## baltic Tree object
    mrcas = { node.traits['clade_name']: node 
             for node in tree.Objects if 'clade_name' in node.traits
            and node.traits['clade_name'] != 'DENV2_AMERICAN'}
    tree = assign_genotype_attr(tree, mrcas)
    return {'tree': tree, 'mrcas': mrcas, 'genotypes': list(set(mrcas.keys()))}

def assign_genotype_colors(genotypes):
    ''' {'denv2/asianI': viridis[0], ...}'''
    cmaps = [cm.Blues, cm.Greens, cm.Purples, cm.Reds]
    
    if genotypes[0].startswith('DENV'):
        color_dict = {}
        for i, sero in enumerate(['DENV1', 'DENV2', 'DENV3', 'DENV4']):
            cmap = cmaps[i]
            geno = sorted([ g for g in genotypes if g.startswith(sero)])
            cm_subsection = linspace(0.25, 0.75,len(geno))
            colors = [ cmap(g) for g in cm_subsection]
            color_dict.update({g:color for (g,color) in zip(geno, colors)})

    else:
        cmap = cmaps[1]
        genotypes.sort()
        cm_subsection = linspace(0.25, 0.75,len(genotypes))
        colors = [ cmap(g) for g in cm_subsection]
        color_dict = {g:color for (g,color) in zip(genotypes, colors)}

    return color_dict

def load_all_frequencies(mrcas, path=freqs_path):
    '''
    {'south_america': 
            {0: [ 0.1, 0.4, 0.23, ....]},
        }, 
    'pivots': [1900, 1901, ...]
    'genotypes': set('DENV2_AMERICAN', ...)}
    '''    
    raw_frequencies = json.load(open(path, 'r')) ## {'southeast_asia_clade:179':[0.1, 0.23, ...]}
    pivots = raw_frequencies.pop('pivots') # [1917., 1918., ...]
    
    regional_clade_frequencies = defaultdict(dict) ## {'global': {'0': [0.1, 0.23, ...] } }
    for label, freqs in raw_frequencies.items():
        if 'clade:' not in label: #south_america_II, africa_denv4_II
            split_label = label.split('_')

            if 'DENV' in label:
                region = '_'.join(split_label[:-2])
                clade = '_'.join(split_label[-2:])
            else:
                region = '_'.join(split_label[:-1])
                clade = '_'.join(split_label[-1:])
            try:
                clade = mrcas[clade].traits['clade']
            except:
                continue
                
        else: # 'global_clade:0'
            region, clade = label.split('_clade:')
            
        clade = int(clade) # the tree uses integers for clade indices
        regional_clade_frequencies[region][clade] = freqs 
        
    return {'frequencies': dict(regional_clade_frequencies), 
            'pivots': pivots }

def get_genotype_frequencies(mrcas, all_frequencies):
    genotype_frequencies = defaultdict(dict)
    
    for region in all_frequencies.keys():
        for genotype, mrca in mrcas.items():
            mrca_clade = mrca.traits['clade']
            genotype_frequencies[region][genotype] = all_frequencies[region][mrca_clade] 
    return dict(genotype_frequencies)

def make_dataframes(regions, genotype_frequencies, mindate=1970.):
    ''' dataframe with genotypes as columns, pivots as index, region-specific frequencies as values'''
    region_dfs = {}
    for region in regions:
        region_data = frequencies[region]
        df = pd.DataFrame(region_data, index=pivots)
        df = df.loc[df.index[df.index >= mindate]]
        region_dfs[region] = df
    return region_dfs

def annotate_references(tree, path=reference_path):
    refs = pd.read_csv(path, names=['serotype', 'genotype', 'year', 'accession', 'country', 'location'])
    refs['sero_geno'] = refs['serotype']+'_'+refs['genotype']
    ref_map = {acc:geno.upper() for (acc, geno) in zip(refs['accession'], refs['sero_geno'])}
    for k in tree.Objects:
        if k.branchType=='leaf' and k.traits['accession'] in ref_map:
            k.traits['reference_genotype'] = ref_map[k.traits['accession']]
    return tree

# %%
tmp = load_tree_find_mrcas()

# bt.tree with k.traits['genotype'] initially assigned by augur-inferred clade_name trait
tree = tmp['tree']
tree = annotate_references(tree)

# {'DENV2_AMERICAN': <baltic node>}
mrcas = tmp['mrcas']

# ['denv2_american', 'denv1_I', ...]
genotypes = tmp['genotypes']

tmp = load_all_frequencies(mrcas)

# {'south_america': 
#         {0: [ 0.2, 0.26, ....]},
#     }
all_frequencies = tmp['frequencies']
frequencies = get_genotype_frequencies(mrcas, all_frequencies) # {'south_america': {'asianI': []}}

# ['south_america', 'southeast_asia']
regions = frequencies.keys()

# [1917., 1918., ...]
pivots = tmp['pivots']

# {'denv2_american': color}
colors = assign_genotype_colors(genotypes)

# { 'southeast_asia': pd.DataFrame(columns=genotypes, index=pivots, values=frequencies)}
region_dfs = make_dataframes(regions, frequencies)
# Out:
# Tree height: 557.129840
# Tree length: 12359.937990
# annotations present
#
# Numbers of objects in tree: 3219 (1532 nodes and 1687 leaves)
#
# ERROR: Overlapping genotypes DENV3_IV and DENV3_II at index NODE_0000101
# ERROR: Overlapping genotypes DENV3_IV and DENV3_II at index DENV3/PUERTO_RICO/PUERTORICO/1963
# ERROR: Overlapping genotypes DENV3_IV and DENV3_II at index DENV3/PUERTO_RICO/S228762/1963
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000093
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/MUTANTINJI6/1982
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000050
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/PHILIPPINES/ILIPPINES/1983
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000052
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/MALAYSIA/NA/1974
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000054
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/NA/1978
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000055
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000056
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/TAIWAN/466/1995
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/TAIWAN/813KH9408A/1994
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000057
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/AUSTRALIA/TOWNSVILLE/2006
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000058
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/TAIWAN/812KH0908A/2009
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/SINGAPORE/91193/2009
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000059
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/JKTA18/1988
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000060
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/NA/1985
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000061
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/JKTA68/1988
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000063
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/MKS0396/2008
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000064
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/MKS3000/2008
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000065
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/MKS0076/2007
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/MKS0057/2007
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000066
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000067
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000068
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NA/AMI1/2001
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NA/ET209/2000
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000069
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NA/SV0153/2005
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000070
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/EAST_TIMOR/PED109NIID/2005
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NA/SV0193/2005
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000071
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000072
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000073
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/PAPUA_NEW_GUINEA/A/2010
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/AUSTRALIA/TOWNSVILLE/2009
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000074
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/PAPUA_NEW_GUINEA/NA/2008
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000075
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0001831
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FIJI/FIDB185/2014
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FIJI/FIDB186/2014
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000077
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/SOLOMON_ISLANDS/SAL3DM/2013
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/SOLOMON_ISLANDS/SAL1FM/2013
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000078
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000079
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/MKSWS78/2010
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/901437/1998
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000080
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000081
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/N056/2010
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000082
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/SINGAPORE/23167/2015
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NA/SOUTHETIA/2008
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000083
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/CHINA/40/2014
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/AUSTRALIA/CAIRNS/2008
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000085
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000086
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/SINGAPORE/0213/2009
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000087
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/10225/2016
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000088
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/SMGSE052/2012
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/SMGSE005/2012
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000089
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/MKS0098/2007
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000090
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/JKTAD001B/2013
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000091
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NA/AMI4/2012
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000092
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NA/AMI5/2012
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NA/AMI7/2011
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000049
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/INDONESIA/SLEMAN/1978
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000048
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/3050/1990
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000039
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000040
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/WALLIS_AND_FUTUNA/1404838/1989
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NA/TAHITI/1989
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/MARQ356/1989
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/060283/1989
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/1573/1989
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/AUST35523/1989
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0001832
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/150514/1989
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0001833
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/2404147/1989
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/11010122/1989
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000003
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000002
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/6056/1990
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000000
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FIJI/29472/1992
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000001
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/AMERICAN_SAMOA/SADB036/1995
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/AMERICAN_SAMOA/BIDV2973/1995
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000004
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000012
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/COOK_ISLANDS/DB030/1991
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/COOK_ISLANDS/BIDV2972/1991
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0001834
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/MARQ47165/1990
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0001835
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/3228/1992
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/24020510/1990
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000005
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/2956/1992
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/320219/1989
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0001836
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/4190/1992
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/1804956/1991
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000013
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/09022130/1991
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000014
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/11022349/1993
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000015
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/200110185/1993
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000017
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/040124111/1994
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/0303429/1994
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000018
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000019
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/136116/1994
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000020
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/010331/1995
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000022
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/ISLV61132/1996
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/19020064/1995
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000023
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/WALLIS_AND_FUTUNA/0501650/1995
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000024
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/15046183/1996
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000025
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/IDV24881/1996
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/FRENCH_POLYNESIA/04024881/1996
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000026
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/1703750/1995
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0001837
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/230409/1995
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0001838
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0001839
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/2804282/1996
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/1403742/1995
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000031
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/4006/1995
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0001840
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/0804492/1996
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/4186/1995
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000033
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/240418/1995
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000035
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/4197/1995
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/4026/1995
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000036
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000038
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/4690/1996
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/0204306/1996
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index NODE_0000037
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/NEW_CALEDONIA/4631/1996
# ERROR: Overlapping genotypes DENV3_I and DENV3_II at index DENV3/WALLIS_AND_FUTUNA/0902448/1995
# ERROR: Overlapping genotypes DENV3_III and DENV3_II at index NODE_0000105
# ERROR: Overlapping genotypes DENV3_III and DENV3_II at index DENV/INDIA/42/2015
# ERROR: Overlapping genotypes DENV3_III and DENV3_II at index DENV3/INDIA/NIV4481/1966
# ERROR: Overlapping genotypes DENV3_III and DENV3_II at index DENV3/INDIA/481/1966

# %%
print region_dfs['global'].head()
# Out:
#            DENV1_I  DENV1_II  DENV1_IV  DENV1_V  DENV2_ASIANAMERICAN  \
# 1970.0000   0.0072    0.0104    0.0164   0.0089               0.0069
# 1970.0833   0.0074    0.0105    0.0169   0.0092               0.0070
# 1970.1667   0.0076    0.0106    0.0174   0.0095               0.0070
# 1970.2500   0.0078    0.0108    0.0180   0.0098               0.0071
# 1970.3333   0.0080    0.0109    0.0185   0.0101               0.0071
#
#            DENV2_ASIANI  DENV2_COSMOPOLITAN  DENV2_SYLVATIC  DENV3_I  \
# 1970.0000        0.0071              0.0082          0.1859   0.0153
# 1970.0833        0.0072              0.0084          0.1805   0.0154
# 1970.1667        0.0072              0.0085          0.1751   0.0155
# 1970.2500        0.0073              0.0087          0.1697   0.0156
# 1970.3333        0.0073              0.0089          0.1644   0.0157
#
#            DENV3_II  DENV3_III  DENV3_IV  DENV4_I  DENV4_II
# 1970.0000    0.1196     0.0021    0.0044   0.0087    0.0294
# 1970.0833    0.1201     0.0020    0.0044   0.0086    0.0292
# 1970.1667    0.1205     0.0019    0.0043   0.0084    0.0290
# 1970.2500    0.1209     0.0018    0.0043   0.0083    0.0288
# 1970.3333    0.1212     0.0018    0.0042   0.0081    0.0286

# %%
def plot_region_frequencies(region, dfs = region_dfs, date_range = None, pivots=pivots):
    plt.title(region)
    plt.xlabel('Year')
    plt.ylabel('Genotype Frequency')

    freqs = dfs[region]
    if date_range:
        pivots = [i for i in pivots if i > date_range[0] and i < date_range[1]]
        freqs = freqs.ix[pivots]
    
    for genotype, freqs in freqs.iteritems():
        plt.plot(pivots, freqs, color=colors[genotype], label=genotype)   
    
def plot_tree(tree):
    branchWidth=2 ## default branch width
    ll = tree
    xmax = max([k.absoluteTime for k in ll.Objects]) + 0.25

    plt.yticks(size=0)
    
    for k in ll.Objects: ## iterate over objects in tree
        x=k.absoluteTime ## or use absolute time instead
        y=k.y ## get y position from .drawTree that was run earlier, but could be anything else

        xp=k.parent.absoluteTime ## get x position of current object's parent
        if x==None: ## matplotlib won't plot Nones, like root
            x=0.0
        if xp==None:
            xp=x
        try:
            c = colors[k.traits['genotype']] if k.traits.has_key('genotype') else 'gray'
        except:
            c = 'orange'
        if isinstance(k,bt.leaf) or k.branchType=='leaf': ## if leaf...
            s=50 ## tip size can be fixed
            s=50-30*k.height/ll.treeHeight
            
            if 'reference_genotype' in k.traits:
                c = 'red'
                plt.text(xmax,y,k.traits['reference_genotype'], ha='left', zorder=100, color=c)

            plt.scatter(x,y,s=s,facecolor=c,edgecolor='none',zorder=11) ## plot circle for every tip
            plt.scatter(x,y,s=s+0.8*s,facecolor='k',edgecolor='none',zorder=10) ## plot black circle underneath
        elif isinstance(k,bt.node) or k.branchType=='node': ## if node...
            plt.plot([x,x],[k.children[-1].y,k.children[0].y],lw=branchWidth,color=c,ls='-',zorder=9)
            if 'genotype_mrca' in k.traits:
                plt.text(xmax, y, str(k.traits['genotype']), ha='left', zorder=100)
        plt.plot([xp,x],[y,y],lw=branchWidth,color=c,ls='-',zorder=9)
    x0,x1 = plt.xlim()
    plt.xlim((x0, x1*1.1))


def plot_frequencies_and_tree():
    sns.set(style='whitegrid', font_scale = 1.3)
    fig = plt.figure(figsize=(11,8.5))
    gs = gridspec.GridSpec(1,2, width_ratios=[2,1])
    
    globe = plt.subplot(gs[0, 0])
    plot_region_frequencies('global', date_range=[2000., 2017.])
    plt.legend(loc=(2.5,-0.1), title="Dengue Genotypes in Nicaragua", fontsize='large')
    globe.set_ylim([0, 1])
        
    sns.set(style = 'white', font_scale = 1.3)
    treeplot = plt.subplot(gs[0,1])
    plot_tree(tree)
        
    plt.tight_layout()
    plt.show()
    
def plot_subtrees(tree):
    sns.set(style='whitegrid', font_scale=1.3)
    figure = plt.figure(figsize=(10,50))
    serotype_mrcas = [('DENV1', 2109), ('DENV2', 1), ('DENV3', 1458), ('DENV4', 1005)]
    for i, (serotype, mrca) in enumerate(serotype_mrcas, start=1):
        plt.subplot(4, 1,i)
        try:
            mrca = [k for k in tree.Objects if k.branchType=='node' and k.traits['clade'] ==mrca][0]
            subtree = tree.subtree(mrca)
            plot_tree(subtree)
        except:
            print (serotype, mrca)
    plt.tight_layout()
    plt.show()

# %%
def update_mrcas(mrcas=mrcas, tree=tree):
    for genotype, mrca in mrcas.items():
        if not isinstance(mrca, bt.node):
            try:
                mrcas[genotype] = [k for k in tree.nodes if k.traits['clade'] == mrca][0]
            except:
                print genotype, mrca
    genotype_frequencies = get_genotype_frequencies(mrcas, all_frequencies)
    tree = assign_genotype_attr(tree, mrcas)
    region_dfs = make_dataframes(regions, genotype_frequencies)
    return {'frequencies': genotype_frequencies, 'tree': tree, 'region_dfs': region_dfs}

mrcas['DENV1_I'] = 2808
mrcas['DENV1_IV'] = 2497
mrcas['DENV1_V'] = 2110
mrcas['DENV1_II'] = 2491

mrcas['DENV2_AMERICAN'] = 33
mrcas['DENV2_ASIANII'] = 504
mrcas['DENV2_ASIANI'] = 554
mrcas['DENV2_ASIANAMERICAN'] = 663

mrcas['DENV3_III'] = 1810
mrcas['DENV3_I'] = 1637
mrcas['DENV3_V'] = 1628
mrcas['DENV3_II'] = 1463
mrcas['DENV3_IV'] = 1622

# mrcas['DENV4_'] = 
# mrcas['DENV4_'] = 
# mrcas['DENV4_'] = 
# mrcas['DENV4_'] = 


# mrcas['I'] = 13
# mrcas['SYLVATIC'] = 1
genotypes = mrcas.keys()
colors = assign_genotype_colors(genotypes)
tmp = update_mrcas()
frequencies = tmp['frequencies']
tree = tmp['tree']
region_dfs = tmp['region_dfs']

# %%
plot_subtrees(tree)

# %%
plot_frequencies_and_tree()

# %%
region_dfs['global'].to_csv('../../data/frequencies/nicaragua_frequencies.csv')
