# %%
import baltic as bt
from matplotlib import pyplot as plt
from collections import defaultdict
from matplotlib import cm
from numpy import linspace
# %matplotlib inline
import json
import matplotlib.gridspec as gridspec
import math
from itertools import combinations
import pandas as pd
import numpy as np
import seaborn as sns
from pprint import pprint
import math
import sequtils as sue
from scipy.stats import linregress
# Out:
# /Library/Python/2.7/site-packages/matplotlib/__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
tree_path = '/Users/Sidney/nextstrain/augur/dengue/auspice/dengue_all_tree.json'
freqs_path = '/Users/Sidney/nextstrain/augur/dengue/auspice/dengue_all_frequencies.json'
reference_path = '../../data/reference_seqs/genotype_refs_pyke2016.csv'
titer_path = '../../data/katzelnick2015/processed/genotypes_normalized.csv'

# %%
def assign_genotype_attr(tree, mrcas):
    ''' Takes the most basal node with each genotype annotation, 
    propagates the genotype assignment to its monophyletic descendents'''
    
    for k in tree.Objects: # remove old annotations
        k.traits = { key:value for key,value in k.traits.items()
                    if key not in ['genotype', 'genotype_mrca', 'clade_name']}
        
    for genotype, node in mrcas.items():
        node.traits['genotype_mrca'] = True
        node.traits['genotype'] = genotype
        for child in tree.traverse_tree(node, include_all=True):
            if 'genotype' in child.traits:
                if genotype != child.traits['genotype']:
                    print 'ERROR: Overlapping genotypes %s and %s at index %s'%(child.traits['genotype'], genotype, child.index)
            child.traits['genotype'] = genotype
    return tree

def load_tree_find_mrcas(path = tree_path):    
    '''Initially, genotype mrcas are as designated by augur.'''
    tree = bt.loadJSON(path) ## baltic Tree object
    mrcas = { node.traits['clade_name']: node 
             for node in tree.Objects if 'clade_name' in node.traits
            and node.traits['clade_name'] != 'DENV2_AMERICAN'}
    tree = assign_genotype_attr(tree, mrcas)
    return {'tree': tree, 'mrcas': mrcas, 'genotypes': list(set(mrcas.keys()))}

def assign_genotype_colors(genotypes):
    ''' {'denv2/asianI': viridis[0], ...}'''
    cmaps = [cm.Blues, cm.Greens, cm.Purples, cm.Reds]
    
    if genotypes[0].startswith('DENV'):
        color_dict = {}
        for i, sero in enumerate(['DENV1', 'DENV2', 'DENV3', 'DENV4']):
            cmap = cmaps[i]
            geno = sorted([ g for g in genotypes if g.startswith(sero)])
            cm_subsection = linspace(0.25, 0.75,len(geno))
            colors = [ cmap(g) for g in cm_subsection]
            color_dict.update({g:color for (g,color) in zip(geno, colors)})

    else:
        cmap = cmaps[1]
        genotypes.sort()
        cm_subsection = linspace(0.25, 0.75,len(genotypes))
        colors = [ cmap(g) for g in cm_subsection]
        color_dict = {g:color for (g,color) in zip(genotypes, colors)}

    return color_dict

def load_all_frequencies(mrcas, path=freqs_path):
    '''
    {'south_america': 
            {0: [ 0.1, 0.4, 0.23, ....]},
        }, 
    'pivots': [1900, 1901, ...]
    'genotypes': set('DENV2_AMERICAN', ...)}
    '''    
    raw_frequencies = json.load(open(path, 'r')) ## {'southeast_asia_clade:179':[0.1, 0.23, ...]}
    pivots = raw_frequencies.pop('pivots') # [1917., 1918., ...]
    
    regional_clade_frequencies = defaultdict(dict) ## {'global': {'0': [0.1, 0.23, ...] } }
    for label, freqs in raw_frequencies.items():
        if 'clade:' not in label: #south_america_II, africa_denv4_II
            split_label = label.split('_')

            if 'DENV' in label:
                region = '_'.join(split_label[:-2])
                clade = '_'.join(split_label[-2:])
            else:
                region = '_'.join(split_label[:-1])
                clade = '_'.join(split_label[-1:])
            try:
                clade = mrcas[clade].traits['clade']
            except:
                continue
                
        else: # 'global_clade:0'
            region, clade = label.split('_clade:')
            
        clade = int(clade) # the tree uses integers for clade indices
        regional_clade_frequencies[region][clade] = freqs 
        
    return {'frequencies': dict(regional_clade_frequencies), 
            'pivots': pivots }

def get_genotype_frequencies(mrcas, all_frequencies):
    genotype_frequencies = defaultdict(dict)
    
    for region in all_frequencies.keys():
        for genotype, mrca in mrcas.items():
            mrca_clade = mrca.traits['clade']
            genotype_frequencies[region][genotype] = all_frequencies[region][mrca_clade] 
    return dict(genotype_frequencies)

def make_dataframes(regions, genotype_frequencies, mindate=1970.):
    ''' dataframe with genotypes as columns, pivots as index, region-specific frequencies as values'''
    region_dfs = {}
    for region in regions:
        region_data = frequencies[region]
        df = pd.DataFrame(region_data, index=pivots)
        df = df.loc[df.index[df.index >= mindate]]
        region_dfs[region] = df
    return region_dfs

def annotate_references(tree, path=reference_path):
    refs = pd.read_csv(path, names=['serotype', 'genotype', 'year', 'accession', 'country', 'location'])
    refs['sero_geno'] = refs['serotype']+'_'+refs['genotype']
    ref_map = {acc:geno.upper() for (acc, geno) in zip(refs['accession'], refs['sero_geno'])}
    for k in tree.Objects:
        if k.branchType=='leaf' and k.traits['accession'] in ref_map:
            k.traits['reference_genotype'] = ref_map[k.traits['accession']]
    return tree

# %%
tmp = load_tree_find_mrcas()

# bt.tree with k.traits['genotype'] initially assigned by augur-inferred clade_name trait
tree = tmp['tree']
tree = annotate_references(tree)

# {'DENV2_AMERICAN': <baltic node>}
mrcas = tmp['mrcas']

# ['denv2_american', 'denv1_I', ...]
genotypes = tmp['genotypes']

tmp = load_all_frequencies(mrcas)

# {'south_america': 
#         {0: [ 0.2, 0.26, ....]},
#     }
all_frequencies = tmp['frequencies']
frequencies = get_genotype_frequencies(mrcas, all_frequencies) # {'south_america': {'asianI': []}}

# ['south_america', 'southeast_asia']
regions = frequencies.keys()

# [1917., 1918., ...]
pivots = tmp['pivots']

# {'denv2_american': color}
colors = assign_genotype_colors(genotypes)

# { 'southeast_asia': pd.DataFrame(columns=genotypes, index=pivots, values=frequencies)}
region_dfs = make_dataframes(regions, frequencies)
# Out:
# Tree height: 617.925450
# Tree length: 14549.184390
# annotations present
#
# Numbers of objects in tree: 2988 (1425 nodes and 1563 leaves)
#
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000211
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000212
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/MALAYSIA/10245/1997
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000213
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/MALAYSIA/3891/1995
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/MALAYSIA/3928/1995
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000215
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/MALAYSIA/7814/1996
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000216
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/MALAYSIA/8064/1996
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/MALAYSIA/7905/1996
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000217
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000218
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000219
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/AUSTRALIA/TOWNSVILLE/2009
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000220
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/INDONESIA/MKS0390/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/INDONESIA/MKS0483/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000221
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000222
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/SINGAPORE/60330/2011
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/INDONESIA/901530/1998
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000223
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/SINGAPORE/14158/2011
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000224
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/CHINA/GZ5700/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000225
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001711
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/AUSTRALIA/MAREEBA/2003
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000226
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/INDONESIA/N012/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/AUSTRALIA/S9671/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000228
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/CHINA/GZ/2002
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000229
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000230
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/CHINA/GD66/2003
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/CHINA/GD54/2003
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000231
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/CHINA/GZ0203/1993
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/CHINA/02GZ/1971
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000232
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000233
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000234
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000235
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/USA/WESTERNPACIFIC/2002
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NAURU/WESTERNPACIFICDELTA30/1974
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000236
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NAURUISLAND/REFERENCE/1997
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NAURU/ISLANDWESTERNPACIFIC/1974
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000237
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/CHINA/GD03/1991
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000238
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000239
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/PALAU/NA/2000
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000240
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/INDONESIA/MKS2029/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000241
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/INDONESIA/N015/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001712
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/INDONESIA/N013/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001713
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/INDONESIA/N005/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/INDONESIA/N023/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000244
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000245
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/PHILIPPINES/ILIPPINESNIID13/2016
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000246
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/AMERICAN_SAMOA/WS190769/2001
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/USA/HAWO3663/2001
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000247
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/SOUTH_KOREA/DENKOR07/2006
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000248
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000249
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/SINGAPORE/CT3/2012
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/CHINA/SU1/2012
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000250
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/SOUTH_KOREA/DENKOR10/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000251
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV/AUSTRALIA/TULLY/2015
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/CHINA/ZJ08/2013
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000252
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000253
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/INDONESIA/A/1988
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000254
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/PAPUA_NEW_GUINEA/NA/2003
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000255
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000256
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV/PAPUA_NEW_GUINEA/PNGA/2014
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000257
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV/PAPUA_NEW_GUINEA/PNGB/2014
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV/PAPUA_NEW_GUINEA/NA/2011
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000258
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/SOLOMON_ISLANDS/070119/2002
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000259
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/SOLOMON_ISLANDS/SOLOMONISLANDS/2002
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FIJI/NA/2002
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000261
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/MARSHALL_ISLANDS/RMIDB107/2003
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000262
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/MICRONESIA/27/2004
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/MICRONESIA/YAPNIID27/2004
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000263
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000264
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/CHINA/GD/1995
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/CHINA/GZ01/1995
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000265
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000266
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/SEYCHELLES/1480/2004
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/SEYCHELLES/1488/2004
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000268
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRANCE/185/2004
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000269
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/SEYCHELLES/NIID41/2003
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001714
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/MADAGASCAR/MADAGCAR02ATW/2006
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRANCE/281/2004
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000271
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/INDONESIA/901518/1998
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000272
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/CHILE/CHI3336/2002
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000273
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/BIDV2939/2001
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/USA/HAWO3758/2001
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/270515/2001
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000298
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/HAWM2516/2001
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/USA/HAWM3430/2001
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001715
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001716
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/COOK_ISLANDS/COOKISLANDS/2002
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001717
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/FP0705/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001718
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/FP0908/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/FP1104/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000274
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/030585/2002
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000275
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/09041/2004
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001719
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/0301994/2004
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/0501477/2004
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001720
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/250716/2002
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001721
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/010739/2002
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001722
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/0504992/2003
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001723
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/01117/2002
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001724
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/1188/2002
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001725
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/060354/2003
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001726
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/100390/2003
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001727
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/00918/2003
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001728
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/2103753/2003
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001729
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/1807687/2003
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001730
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/0207773/2003
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001731
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/010559/2004
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/160395/2004
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000299
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000312
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000313
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000314
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/0164/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/060125/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000315
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/31018/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001740
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/230174/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001741
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/11029/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001742
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/28097/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001743
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/070133/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001744
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/23/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001745
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/060164/2009
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001746
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/076/2009
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/160120/2009
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000323
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000324
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/0192/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001747
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/183/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001748
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/310176/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001749
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/070138/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/270207/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000328
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/14008/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001750
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000330
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/01092/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/59/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000331
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/110/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001827
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/101/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001751
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001752
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/220181/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/250193/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000332
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/10019/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001753
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/18001/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/074/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001828
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001732
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/06062/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001733
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000310
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/040152/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/13028/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001734
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/200157/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001735
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000304
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/03052/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/240159/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001736
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000302
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/21066/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/04034/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001737
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/001/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001738
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/64/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001739
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/200249/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/120113/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000337
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FIJI/B/2006
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FIJI/A/2006
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/COOK_ISLANDS/COOKISLANDS/2006
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000349
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/230201/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001829
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/290109/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001754
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/090/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001755
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/04037/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000353
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001756
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/13076/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001757
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/02030/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/260153/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000356
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/110160/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001758
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/38/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001759
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/0186/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001760
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/12048/2009
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001761
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/180138/2009
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/060120/2009
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001762
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001763
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000345
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/25064/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001764
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/040123/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001765
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/221/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/13039/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001766
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/270110/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001767
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FRENCH_POLYNESIA/08092/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001768
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/TONGA/NGA/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/180286/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000361
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001769
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/030418/2007
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000363
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/04575/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001770
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/14014415/2009
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/1302229/2009
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000365
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/110284/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001771
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/250468/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001772
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/1403629/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001773
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001774
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/04048/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001775
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/27014311/2009
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001776
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/240772/2009
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/5142/2008
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000372
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001777
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/30013639/2009
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/2503584/2009
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000374
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000387
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/VANUATU/180358/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000388
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/190759/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/230627/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001778
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/290652/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001779
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/030841/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/190764/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001780
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/070960/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001781
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/200777/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001782
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001783
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/0801138/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/15096/2010
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000375
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FIJI/B/2011
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001784
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000377
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/FIJI/B/2012
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000378
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NIUE/A/2012
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NIUE/B/2012
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001785
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0001786
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/230873/2012
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/170262/2012
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index NODE_0000381
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/270911/2012
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/270920/2012
# ERROR: Overlapping genotypes DENV1_IV and DENV1_I at index DENV1/NEW_CALEDONIA/0489/2012
# ERROR: Overlapping genotypes DENV1_II and DENV1_I at index NODE_0000207
# ERROR: Overlapping genotypes DENV1_II and DENV1_I at index NODE_0000208
# ERROR: Overlapping genotypes DENV1_II and DENV1_I at index DENV1/THAILAND/16007PDK13/1989
# ERROR: Overlapping genotypes DENV1_II and DENV1_I at index DENV1/THAILAND/16007/1964
# ERROR: Overlapping genotypes DENV1_II and DENV1_I at index NODE_0000209
# ERROR: Overlapping genotypes DENV1_II and DENV1_I at index DENV1/THAILAND/6147/1960
# ERROR: Overlapping genotypes DENV1_II and DENV1_I at index DENV1/THAILAND/AI6147/1960
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/PERU/IQT6152/2000
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000049
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000050
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/MOSQ/1986
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000052
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/NA/1990
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/38159RJ/1989
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000053
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/36034RJ/1988
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000054
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/01B01021093/2008
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000055
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/41111PE/1997
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/BEH527543/1994
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000057
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000058
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/52082PE/1998
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000059
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/88463PE/2002
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/59049PE/1999
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000060
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000061
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/SB05780502/2001
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/233/1997
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000062
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/MR/2001
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000063
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/74488PE/2001
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000064
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/40604PE/1997
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/21814PE/1996
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000065
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000066
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000068
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/COSTA_RICA/DM12/2013
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000069
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/NICARAGUA/BIDV7672/2011
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000070
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/VENEZUELA/61081/2007
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/VENEZUELA/610/2006
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001800
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/VENEZUELA/OBT1298/2000
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000071
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000072
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/USA/DB168/2014
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000073
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/USA/DB166/2014
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/USA/DB169/2014
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000074
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000075
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/NICARAGUA/BIDV664/2004
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/NICARAGUA/BIDV2642/2004
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000076
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000077
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/NICARAGUA/BIDV617/2004
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000078
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000079
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/USA/KW10AG/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000080
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/CHINA/ZJ01/2013
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/USA/BOLKW0/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000081
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000082
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/NICARAGUA/BIDV7684/2012
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000083
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/NICARAGUA/BIDV7686/2012
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/NICARAGUA/BIDV7685/2012
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000084
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000085
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/NICARAGUA/5353/2014
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/COSTA_RICA/DE90/2014
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000086
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/COSTA_RICA/DE49/2013
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/COSTA_RICA/DE70/2013
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000087
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/NICARAGUA/BIDV1070/2005
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000088
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MEXICO/G7/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000089
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000090
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MEXICO/C7/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000091
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MEXICO/H11/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MEXICO/C16/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000092
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MEXICO/B5/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MEXICO/C13/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001801
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MEXICO/F/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001802
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MEXICO/B13/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001803
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MEXICO/C8/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001804
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MEXICO/H17/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001805
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MEXICO/1/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001806
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MEXICO/A5/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001807
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MEXICO/I15/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MEXICO/A7/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000101
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000102
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/VENEZUELA/BIDV2171/1999
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000103
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/SPAIN/BIDV3376/1998
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/SPAIN/BIDV3377/1998
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000104
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/SPAIN/BIDV3379/2001
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000105
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000106
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/SPAIN/BIDV3388/2007
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/SPAIN/BIDV3387/2007
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000107
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/SPAIN/BIDV3391/2008
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000108
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG37945/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000109
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/VENEZUELA/61084/2007
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000110
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/VENEZUELA/61068/2006
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/SPAIN/BIDV3380/2005
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000112
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/SPAIN/BIDV3378/1999
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000113
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG28425/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000114
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000115
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000116
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/PUERTO_RICO/BIDV7705/2012
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/USA/ARC31/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000117
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001834
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/PUERTO_RICO/BIDV852/2006
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001808
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/USA/MARTINFLA/2013
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000118
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MARTINIQUE/481013035/2008
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/MARTINIQUE/480513060/2008
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000121
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/JAMAICA/17388/2012
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000122
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/HAITI/1207/2014
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000123
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/USA/ARC30/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000124
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/PUERTO_RICO/BIDV8185/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001809
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/USA/NYS31368/2013
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/PUERTO_RICO/BIDV7706/2012
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000127
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/PUERTO_RICO/BIDV8183/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/PUERTO_RICO/BIDV8181/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000128
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000142
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG14635/2009
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG13405/2009
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000136
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000138
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG28226/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG25001/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000137
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG12589/2009
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG12560/2009
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000147
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG14076/2009
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000151
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG27486/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG15417/2009
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000148
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG12447/2009
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000149
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/12898PE/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/14985PE/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000130
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG12188/2009
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000131
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/SJRP354/2011
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000132
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/SJRP395/2011
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000133
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BRAZIL/SJRP287/2011
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001812
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV/BRAZIL/SJRP442/2011
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV/BRAZIL/SJRP437/2011
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001835
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG13708/2009
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001836
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/ARGENTINA/HNRG13154/2009
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001810
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/BOLIVIA/FSB3363/2010
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0001811
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV1/CHINA/AQZK01AH/2016
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000145
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV/BRAZIL/SJRP422/2011
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index NODE_0000146
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV/BRAZIL/SJRP430/2011
# ERROR: Overlapping genotypes DENV1_I and DENV1_V at index DENV/BRAZIL/SJRP395/2011

# %%
print region_dfs['southeast_asia'].head()
# Out:
#            DENV1_I  DENV1_II  DENV1_IV  DENV1_V  DENV2_ASIANAMERICAN  \
# 1970.0000   0.1584    0.0036    0.0092      0.0               0.0764
# 1970.0833   0.1577    0.0035    0.0092      0.0               0.0766
# 1970.1667   0.1572    0.0035    0.0092      0.0               0.0769
# 1970.2500   0.1566    0.0034    0.0091      0.0               0.0772
# 1970.3333   0.1561    0.0033    0.0091      0.0               0.0774
#
#            DENV2_ASIANI  DENV2_COSMOPOLITAN  DENV2_SYLVATIC  DENV3_I  \
# 1970.0000        0.0757              0.0623          0.0445   0.0433
# 1970.0833        0.0759              0.0625          0.0448   0.0429
# 1970.1667        0.0762              0.0628          0.0452   0.0425
# 1970.2500        0.0765              0.0630          0.0456   0.0420
# 1970.3333        0.0767              0.0632          0.0459   0.0417
#
#            DENV3_II  DENV3_III  DENV3_IV  DENV4_I  DENV4_II  DENV4_SYLVATIC
# 1970.0000    0.0519        0.0       0.0   0.0399    0.0568          0.0269
# 1970.0833    0.0514        0.0       0.0   0.0401    0.0574          0.0274
# 1970.1667    0.0509        0.0       0.0   0.0402    0.0580          0.0278
# 1970.2500    0.0505        0.0       0.0   0.0404    0.0585          0.0283
# 1970.3333    0.0500        0.0       0.0   0.0405    0.0589          0.0288

# %%
def plot_region_frequencies(region, dfs = region_dfs, date_range = None, pivots=pivots):
    plt.title(region)
    plt.xlabel('Year')
    plt.ylabel('Genotype Frequency')

    freqs = dfs[region]
    if date_range:
        pivots = [i for i in pivots if i > date_range[0] and i < date_range[1]]
        freqs = freqs.ix[pivots]
    
    for genotype, freqs in freqs.iteritems():
        plt.plot(pivots, freqs, color=colors[genotype], label=genotype)   
    
def plot_tree(tree):
    branchWidth=2 ## default branch width
    ll = tree
    xmax = max([k.absoluteTime for k in ll.Objects]) + 0.25

    plt.yticks(size=0)
    
    for k in ll.Objects: ## iterate over objects in tree
        x=k.absoluteTime ## or use absolute time instead
        y=k.y ## get y position from .drawTree that was run earlier, but could be anything else

        xp=k.parent.absoluteTime ## get x position of current object's parent
        if x==None: ## matplotlib won't plot Nones, like root
            x=0.0
        if xp==None:
            xp=x
        try:
            c = colors[k.traits['genotype']] if k.traits.has_key('genotype') else 'gray'
        except:
            c = 'orange'
        if isinstance(k,bt.leaf) or k.branchType=='leaf': ## if leaf...
            s=50 ## tip size can be fixed
            s=50-30*k.height/ll.treeHeight
            
            if 'reference_genotype' in k.traits:
                c = 'red'
                plt.text(xmax,y,k.traits['reference_genotype'], ha='left', zorder=100, color=c)

            plt.scatter(x,y,s=s,facecolor=c,edgecolor='none',zorder=11) ## plot circle for every tip
            plt.scatter(x,y,s=s+0.8*s,facecolor='k',edgecolor='none',zorder=10) ## plot black circle underneath
        elif isinstance(k,bt.node) or k.branchType=='node': ## if node...
            plt.plot([x,x],[k.children[-1].y,k.children[0].y],lw=branchWidth,color=c,ls='-',zorder=9)

            if 'genotype_mrca' in k.traits:
#                 plt.text(xmax, y, str(k.traits['genotype']), ha='left', zorder=100)
                plt.text(x,y,str(k.traits['clade']), ha='right', zorder=100)
                try:
                    plt.text(k.parent.absoluteTime, k.parent.y, str(k.parent.traits['clade']), ha='right', zorder=100)
                except:
                    pass
        plt.plot([xp,x],[y,y],lw=branchWidth,color=c,ls='-',zorder=9)
    x0,x1 = plt.xlim()
    plt.xlim((x0, x1*1.1))


def plot_frequencies_and_tree():
    sns.set(style='whitegrid', font_scale = 1.3)
    fig = plt.figure(figsize=(11,8.5))
    gs = gridspec.GridSpec(3,3, width_ratios=[1,1,2], )
    
    globe = plt.subplot(gs[0, :-1])
    plot_region_frequencies('global', date_range=[1985., 1995.])
    plt.legend(loc=(2.5,-0.1), title="Dengue Genotypes", fontsize='large')
    globe.set_ylim([0, 1])

    south_america = plt.subplot(gs[1,:-1])
    plot_region_frequencies('south_america',date_range=[1985., 1995.])
    south_america.set_ylim([0, 1])
    
    southeast_asia = plt.subplot(gs[2, :-1])
    plot_region_frequencies('southeast_asia',date_range=[1985., 2014.])
    southeast_asia.set_ylim([0, 1])
        
    sns.set(style = 'white', font_scale = 1.3)
    treeplot = plt.subplot(gs[:,-1])
    plot_tree(tree)
        
    plt.tight_layout()
    plt.show()
    
def plot_subtrees(tree):
    sns.set(style='whitegrid', font_scale=1.3)
    figure = plt.figure(figsize=(10,50))
    serotype_mrcas = [('DENV1', 1857), ('DENV2', 1), ('DENV3', 1384), ('DENV4', 967)]
    for i, (serotype, mrca) in enumerate(serotype_mrcas, start=1):
        plt.subplot(4, 1,i)
        mrca = [k for k in tree.Objects if k.branchType=='node' and k.traits['clade'] ==mrca][0]
        subtree = tree.subtree(mrca)
        plot_tree(subtree)
    plt.tight_layout()
    plt.show()

# %%
def update_mrcas(mrcas=mrcas, tree=tree):
    for genotype, mrca in mrcas.items():
        if not isinstance(mrca, bt.node):
            mrcas[genotype] = [k for k in tree.nodes if k.traits['clade'] == mrca][0]
    genotype_frequencies = get_genotype_frequencies(mrcas, all_frequencies)
    tree = assign_genotype_attr(tree, mrcas)
    region_dfs = make_dataframes(regions, genotype_frequencies)
    return {'frequencies': genotype_frequencies, 'tree': tree, 'region_dfs': region_dfs}

mrcas['DENV1_I'] = 1858
mrcas['DENV1_IV'] = 2231
mrcas['DENV1_V'] = 2589
mrcas['DENV1_II'] = 2582

mrcas['DENV2_AMERICAN'] = 33
mrcas['DENV2_ASIANII'] = 494
# mrcas['DENV2_ASIANI'] = 
# mrcas['DENV2_'] = 

mrcas['DENV3_III'] = 1583
# mrcas['DENV3_I'] = 1459
# mrcas['DENV3_V'] = 1454
# mrcas['DENV3_II'] = 1392
# mrcas['DENV3_'] = 

# mrcas['DENV4_'] = 
# mrcas['DENV4_'] = 
# mrcas['DENV4_'] = 
# mrcas['DENV4_'] = 


# mrcas['I'] = 13
# mrcas['SYLVATIC'] = 1
genotypes = mrcas.keys()
colors = assign_genotype_colors(genotypes)
tmp = update_mrcas()
frequencies = tmp['frequencies']
tree = tmp['tree']
region_dfs = tmp['region_dfs']

# %%
plot_subtrees(tree)

# %%
plot_frequencies_and_tree()
# pprint({g : m.traits['clade'] for g,m in mrcas.items()})
